# %%
from PIL import Image
import matplotlib.pyplot as plt
#image_path = 'Figure_1_1.png'
plt.figure(figsize=(9,9))
for i in range(1,5):
    plt.subplot(4,1, i)
    image_path = 'Figure_1_'+ str(i) + '.png'
    plt.imshow(Image.open(image_path))
plt.show()
