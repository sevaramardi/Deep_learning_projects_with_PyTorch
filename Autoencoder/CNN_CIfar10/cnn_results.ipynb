# %%
from PIL import Image
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(1,6):
    plt.subplot(5,1, i)
    image_path = 'Figure_'+str(i)+'.png'
    plt.imshow(Image.open(image_path))
plt.show()
